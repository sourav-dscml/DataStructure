# %% [markdown]
# ## Exercise: Hash Table

# %% [markdown]
# nyc_weather.csv contains new york city weather for first few days in the month of January.
#
# Write a program that can answer following,
#
# What was the average temperature in first week of Jan
#
# What was the maximum temperature in first 10 days of Jan
#
# Figure out data structure that is best for this problem

# %%
# file = open('nyc_weather.csv', 'r')
# # text = file.read()
# temp=[]
# for item in file:

arr = []

with open("nyc_weather.csv","r") as f:
    for line in f:
        tokens = line.split(',')
        try:
            temperature = int(tokens[1])
            arr.append(temperature)
        except:
            print("Invalid temperature.Ignore the row")

# %%
temp=[]
with open('nyc_weather.csv', 'r') as f:
    for i in f:
        if i.split(',')[1] != 'temperature(F)\n':
            temp.append(int(i.split(',')[1][:2]) )
print(temp)
# Out:
# [27, 31, 23, 34, 37, 38, 29, 30, 35, 30]

# %%
sum = 0
for i in range(7):
    sum = sum + temp[i]
avg = sum/7
print(avg)
# Out:
# 31.285714285714285

# %%
dicttemp = {}

with open("nyc_weather.csv","r") as f:
    for line in f:
        tokens = line.split(',')
        try:
            dicttemp[tokens[0]] = int(tokens[1])
        except:
            print("Invalid temperature.Ignore the row")
print(dicttemp)
# Out:
# Invalid temperature.Ignore the row
# {'Jan 1': 27, 'Jan 2': 31, 'Jan 3': 23, 'Jan 4': 34, 'Jan 5': 37, 'Jan 6': 38, 'Jan 7': 29, 'Jan 8': 30, 'Jan 9': 35, 'Jan 10': 30}

# %%
dicttemp
# Out:
# {'Jan 1': 27,
#  'Jan 2': 31,
#  'Jan 3': 23,
#  'Jan 4': 34,
#  'Jan 5': 37,
#  'Jan 6': 38,
#  'Jan 7': 29,
#  'Jan 8': 30,
#  'Jan 9': 35,
#  'Jan 10': 30}

# %%
file =  open('poem.txt','r') 
text = file.read()
text =  text.strip()
import regex as re
text = re.sub('[,;.!:]','',text)

# %%
# text = text.lower()

# %%
wordcnt = {}
cntr = 0
for i in text.split():
    
    print(i)
    if i not in wordcnt:
        
        wordcnt[i] = 1
    else:
        print(i)
#         cntr=cntr+1
        wordcnt[i] += 1
# print(wordcnt)
# Out:
# Two
# roads
# diverged
# in
# a
# yellow
# wood
# And
# sorry
# I
# could
# not
# travel
# both
# And
# And
# be
# one
# traveler
# long
# I
# I
# stood
# And
# And
# looked
# down
# one
# one
# as
# far
# as
# as
# I
# I
# could
# could
# To
# where
# it
# bent
# in
# in
# the
# undergrowth
# Then
# took
# the
# the
# other
# as
# as
# just
# as
# as
# fair
# And
# And
# having
# perhaps
# the
# the
# better
# claim
# Because
# it
# it
# was
# grassy
# and
# wanted
# wear
# Though
# as
# as
# for
# that
# the
# the
# passing
# there
# Had
# worn
# them
# really
# about
# the
# the
# same
# And
# And
# both
# both
# that
# that
# morning
# equally
# lay
# In
# leaves
# no
# step
# had
# trodden
# black
# Oh
# I
# I
# kept
# the
# the
# first
# for
# for
# another
# day
# Yet
# knowing
# how
# way
# leads
# on
# to
# way
# way
# I
# I
# doubted
# if
# I
# I
# should
# ever
# come
# back
# I
# I
# shall
# be
# be
# telling
# this
# with
# a
# a
# sigh
# Somewhere
# ages
# and
# and
# ages
# ages
# hence
# Two
# Two
# roads
# roads
# diverged
# diverged
# in
# in
# a
# a
# wood
# wood
# and
# and
# Iâ€”
# I
# I
# took
# took
# the
# the
# one
# one
# less
# traveled
# by
# And
# And
# that
# that
# has
# made
# all
# the
# the
# difference

# %%
wordcnt
# Out:
# {'Two': 2,
#  'roads': 2,
#  'diverged': 2,
#  'in': 3,
#  'a': 3,
#  'yellow': 1,
#  'wood': 2,
#  'And': 6,
#  'sorry': 1,
#  'I': 8,
#  'could': 2,
#  'not': 1,
#  'travel': 1,
#  'both': 2,
#  'be': 2,
#  'one': 3,
#  'traveler': 1,
#  'long': 1,
#  'stood': 1,
#  'looked': 1,
#  'down': 1,
#  'as': 5,
#  'far': 1,
#  'To': 1,
#  'where': 1,
#  'it': 2,
#  'bent': 1,
#  'the': 8,
#  'undergrowth': 1,
#  'Then': 1,
#  'took': 2,
#  'other': 1,
#  'just': 1,
#  'fair': 1,
#  'having': 1,
#  'perhaps': 1,
#  'better': 1,
#  'claim': 1,
#  'Because': 1,
#  'was': 1,
#  'grassy': 1,
#  'and': 3,
#  'wanted': 1,
#  'wear': 1,
#  'Though': 1,
#  'for': 2,
#  'that': 3,
#  'passing': 1,
#  'there': 1,
#  'Had': 1,
#  'worn': 1,
#  'them': 1,
#  'really': 1,
#  'about': 1,
#  'same': 1,
#  'morning': 1,
#  'equally': 1,
#  'lay': 1,
#  'In': 1,
#  'leaves': 1,
#  'no': 1,
#  'step': 1,
#  'had': 1,
#  'trodden': 1,
#  'black': 1,
#  'Oh': 1,
#  'kept': 1,
#  'first': 1,
#  'another': 1,
#  'day': 1,
#  'Yet': 1,
#  'knowing': 1,
#  'how': 1,
#  'way': 2,
#  'leads': 1,
#  'on': 1,
#  'to': 1,
#  'doubted': 1,
#  'if': 1,
#  'should': 1,
#  'ever': 1,
#  'come': 1,
#  'back': 1,
#  'shall': 1,
#  'telling': 1,
#  'this': 1,
#  'with': 1,
#  'sigh': 1,
#  'Somewhere': 1,
#  'ages': 2,
#  'hence': 1,
#  'Iâ€”': 1,
#  'less': 1,
#  'traveled': 1,
#  'by': 1,
#  'has': 1,
#  'made': 1,
#  'all': 1,
#  'difference': 1}
