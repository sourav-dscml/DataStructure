# %%
class Tree():
    def __init__(self,data):
        self.data = data
        self.children= []
        self.parent = None
        
    def create_node(self, child):
        child.parent=self
        self.children.append(child)
        
    def get_level(self):
        level = 0
        p = self.parent
        
        while p:
            level = level + 1
            p = p.parent
        return level
            
        
    def print_tree(self,level):
        spaces = ' ' * self.get_level()*3
        mark = spaces+'|__' if self.parent else ''
        print(mark + self.data)
        if self.children:
            if self.get_level() in range (level):
                for c in self.children:
                    c.print_tree(level)
        
if __name__ == '__main__':
    root = Tree('Global')
    India = Tree('India')
    
    Gujarat = Tree('Gujarat')
    karnataka = Tree('karnataka')
    
    Gujarat.create_node(Tree('Ahmdabad'))
    Gujarat.create_node(Tree('Baroda'))
    
    karnataka.create_node(Tree('Bengalore'))
    karnataka.create_node(Tree('Mysore'))
    
    India.create_node(Gujarat)
    India.create_node(karnataka)
    
    usa = Tree('USA')
    
    nj = Tree('New Jersey')
    cal = Tree('California')
    
    nj.create_node(Tree('Prinston'))
    nj.create_node(Tree('Trenton'))
    
    cal.create_node(Tree('San Fransisco'))
    cal.create_node(Tree('Mountain View'))
    cal.create_node(Tree('Palo Alto'))
    
    usa.create_node(nj)
    usa.create_node(cal)
    
    root.create_node(India)
    root.create_node(usa)
    
    root.print_tree(3)
# Out:
# Global
#    |__India
#       |__Gujarat
#          |__Ahmdabad
#          |__Baroda
#       |__karnataka
#          |__Bengalore
#          |__Mysore
#    |__USA
#       |__New Jersey
#          |__Prinston
#          |__Trenton
#       |__California
#          |__San Fransisco
#          |__Mountain View
#          |__Palo Alto

# %%
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
        self.parent = None

    def get_level(self):
        level = 0
        p = self.parent
        while p:
            level += 1
            p = p.parent

        return level

    def print_tree(self):
        spaces = ' ' * self.get_level() * 3
        prefix = spaces + "|__" if self.parent else ""
        print(prefix + self.data)
        if self.children:
            for child in self.children:
                child.print_tree()

    def add_child(self, child):
        child.parent = self
        self.children.append(child)

def build_product_tree():
    root = TreeNode("Electronics")

    laptop = TreeNode("Laptop")
    laptop.add_child(TreeNode("Mac"))
    laptop.add_child(TreeNode("Surface"))
    laptop.add_child(TreeNode("Thinkpad"))

    cellphone = TreeNode("Cell Phone")
    cellphone.add_child(TreeNode("iPhone"))
    cellphone.add_child(TreeNode("Google Pixel"))
    cellphone.add_child(TreeNode("Vivo"))

    tv = TreeNode("TV")
    tv.add_child(TreeNode("Samsung"))
    tv.add_child(TreeNode("LG"))

    root.add_child(laptop)
    root.add_child(cellphone)
    root.add_child(tv)

    root.print_tree()

if __name__ == '__main__':
    build_product_tree()
# Out:
# Electronics
#    |__Laptop
#       |__Mac
#       |__Surface
#       |__Thinkpad
#    |__Cell Phone
#       |__iPhone
#       |__Google Pixel
#       |__Vivo
#    |__TV
#       |__Samsung
#       |__LG
